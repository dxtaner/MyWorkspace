# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://www.imdb.com/chart/top/"

# %%
page=requests.get(url)

# %%
page
# Out:
# <Response [403]>

# %%
page.content
# Out:
# b'<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n</body>\r\n</html>\r\n'

# %%
#parse movie names
movies = []
for movie in scrapped_movies:
    movie = movie.get_text().replace('\n',"")
    movie=  movie.strip(" ")
    movies.append(movie)
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 3>()
#       1 #parse movie names
#       2 movies = []
# ----> 3 for movie in scrapped_movies:
#       4     movie = movie.get_text().replace('\n',"")
#       5     movie=  movie.strip(" ")
#
# NameError: name 'scrapped_movies' is not defined

# %%
scrapped_ratings = soup.find_all('td',class_='ratingColumn imdbRating')
scrapped_ratings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 scrapped_ratings = soup.find_all('td',class_='ratingColumn imdbRating')
#       2 scrapped_ratings
#
# NameError: name 'soup' is not defined

# %%
#parse movie names
ratings = []
for rating in scrapped_ratings:
    rating = rating.get_text().replace('\n',"")
    rating =  rating.strip(" ")
    ratings.append(rating)
ratings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 3>()
#       1 #parse movie names
#       2 ratings = []
# ----> 3 for rating in scrapped_ratings:
#       4     rating = rating.get_text().replace('\n',"")
#       5     rating =  rating.strip(" ")
#
# NameError: name 'scrapped_ratings' is not defined

# %%
data=pd.DataFrame()
data['Movie Names']=movies
data['Ratings']=ratings
data.head()
# Out:
# Empty DataFrame
# Columns: [Movie Names, Ratings]
# Index: []

# %%
data.to_csv('IMDB Top Movies.csv',index = False)
