# %%
import numpy as np
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([6,7,8,9,10])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr2
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
arr1 + arr2
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
arr1 * arr2  # Inner Product(İç Çarpım)
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
arr1 + 10
# Out:
# array([11, 12, 13, 14, 15])

# %%
arr1 - 10
# Out:
# array([-9, -8, -7, -6, -5])

# %%
arr2 - 2
# Out:
# array([4, 5, 6, 7, 8])

# %%
arr1 / 3
# Out:
# array([0.33333333, 0.66666667, 1.        , 1.33333333, 1.66666667])

# %%
arr2 ** 2
# Out:
# array([ 36,  49,  64,  81, 100], dtype=int32)

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.sqrt(arr1)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        , 2.23606798])
