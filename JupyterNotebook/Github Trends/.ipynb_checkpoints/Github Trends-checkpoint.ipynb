# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
page = requests.get('https://github.com/trending')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
repo = soup.find(class_="box")

# %%
file_name = "Github_Trending_Today.csv"
# set newline to be '' so that that new rows are appended without skipping any
f = csv.writer(open(file_name, 'w', newline=''))

# %%
file_name = "Github_Trending_Today.csv"
# set newline to be '' so that that new rows are appended without skipping any
f = csv.writer(open(file_name, 'w', newline=''))

# %%
for repo in repo_list:
    
    developerandreponame = repo.find(class_='h3 lh-condensed').text.strip()
    # find the first occurance of class octicon octicon-star and get the text from the parent (which is the number of stars)
    stars = repo.find(class_='octicon octicon-star').parent.text.strip()
    # strip() all to remove leading and traling white spaces
    print('developerandreponame', developerandreponame)
    print('stars', stars)
    # add the information as a row into the csv table
    # write a new row as a header
f.writerow(['Developer and Repo Name', 'Number of Stars'])    
f.writerow([developerandreponame ,stars])
# Out:
# developerandreponame BuilderIO /
#
#       gpt-crawler
# stars 8,854
# developerandreponame lllyasviel /
#
#       Fooocus
# stars 15,670
# developerandreponame blakeblackshear /
#
#       frigate
# stars 11,546
# developerandreponame abi /
#
#       screenshot-to-code
# stars 14,527
# developerandreponame PowerShell /
#
#       PowerShell
# stars 41,890
# developerandreponame xuchengsheng /
#
#       spring-reading
# stars 1,699
# developerandreponame zoonk /
#
#       uneebee
# stars 802
# developerandreponame AppFlowy-IO /
#
#       AppFlowy
# stars 41,043
# developerandreponame cxli233 /
#
#       FriendsDontLetFriends
# stars 2,687
# developerandreponame yl4579 /
#
#       StyleTTS2
# stars 2,227
# developerandreponame lxfater /
#
#       inpaint-web
# stars 934
# developerandreponame roc-lang /
#
#       roc
# stars 2,693
# developerandreponame louislam /
#
#       dockge
# stars 1,772
# developerandreponame thewh1teagle /
#
#       mobslide
# stars 200
# developerandreponame tldraw /
#
#       make-real-starter
# stars 883
# developerandreponame 0x90n /
#
#       InfoSec-Black-Friday
# stars 2,618
# developerandreponame jerryjliu /
#
#       create_llama_projects
# stars 409
# developerandreponame jordansinger /
#
#       build-it-figma-ai
# stars 174
# developerandreponame trungdq88 /
#
#       Awesome-Black-Friday-Cyber-Monday
# stars 2,743
# developerandreponame sickcodes /
#
#       Docker-OSX
# stars 32,575
# developerandreponame rsms /
#
#       inter
# stars 16,183
# developerandreponame angular /
#
#       angular-cli
# stars 26,319
# developerandreponame emilwallner /
#
#       Screenshot-to-code
# stars 14,644
# developerandreponame pytorch-labs /
#
#       segment-anything-fast
# stars 594
# developerandreponame louislam /
#
#       uptime-kuma
# stars 41,098
# 42
