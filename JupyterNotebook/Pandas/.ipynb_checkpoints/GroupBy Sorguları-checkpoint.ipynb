# %% [markdown]
# # GroupBy Sorguları

# %%
import numpy as np
import pandas as pd

# %%
dataset = {
        "Departman":["Bilişim","İnsan Kaynakları","Üretim","Üretim","Bilişim","İnsan Kaynakları"],
        "Çalışan": ["Taner","Esra","Samir","Zeynep","Arda","Messi"],
        "Maaş":[3000,3500,2500,4500,4000,2000]
        }

# %%
dataset
# Out:
# {'Departman': ['Bilişim',
#   'İnsan Kaynakları',
#   'Üretim',
#   'Üretim',
#   'Bilişim',
#   'İnsan Kaynakları'],
#  'Çalışan': ['Taner', 'Esra', 'Samir', 'Zeynep', 'Arda', 'Messi'],
#  'Maaş': [3000, 3500, 2500, 4500, 4000, 2000]}

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#           Departman Çalışan  Maaş
# 0           Bilişim   Taner  3000
# 1  İnsan Kaynakları    Esra  3500
# 2            Üretim   Samir  2500
# 3            Üretim  Zeynep  4500
# 4           Bilişim    Arda  4000
# 5  İnsan Kaynakları   Messi  2000

# %%
DepGroup = df.groupby("Departman")

# %%
DepGroup

# %%
DepGroup.sum()
# Out:
#                   Maaş
# Departman
# Bilişim           7000
# Üretim            7000
# İnsan Kaynakları  5500

# %%
TotalPriceB = DepGroup.sum().loc["Bilişim"]

# %%
TotalPriceB
# Out:
# Maaş    7000
# Name: Bilişim, dtype: int64

# %%
int(TotalPriceB)
# Out:
# 7000

# %%
df.groupby("Departman").count()
# Out:
#                   Çalışan  Maaş
# Departman
# Bilişim                 2     2
# Üretim                  2     2
# İnsan Kaynakları        2     2

# %%
df.groupby("Departman").max()
# Out:
#                  Çalışan  Maaş
# Departman
# Bilişim            Taner  4000
# Üretim            Zeynep  4500
# İnsan Kaynakları   Messi  3500

# %%
minPriceB = df.groupby("Departman").min()["Maaş"]["Bilişim"]

# %%
minPriceB
# Out:
# 3000

# %%
averagePriceB = df.groupby("Departman").mean().loc["Bilişim"]["Maaş"]

# %%
averagePriceB
# Out:
# 3500.0
